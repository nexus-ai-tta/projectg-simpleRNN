# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[7568, 5854, 432, 1477],
#  [7568, 5854, 432, 4551],
#  [7568, 9630, 432, 3607],
#  [2993, 6214, 5784, 9469, 9684],
#  [2993, 6214, 5784, 9469, 2014],
#  [4047, 7568, 9110, 432, 1077],
#  [73, 6929, 5521, 9469]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 7568 5854  432 1477]
#  [   0    0    0    0 7568 5854  432 4551]
#  [   0    0    0    0 7568 9630  432 3607]
#  [   0    0    0 2993 6214 5784 9469 9684]
#  [   0    0    0 2993 6214 5784 9469 2014]
#  [   0    0    0 4047 7568 9110  432 1077]
#  [   0    0    0    0   73 6929 5521 9469]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (7, 8, 10)             │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# array([[[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.01201606,  0.01414626,  0.03860701,  0.01598797,
#           0.04391552,  0.01895965,  0.03589279,  0.04442103,
#          -0.00563138,  0.00528693],
#         [-0.01244445, -0.02957804,  0.00261693,  0.02056589,
#          -0.02634252,  0.00701339,  0.03048749, -0.02724193,
#          -0.02480011, -0.02679308],
#         [-0.0077255 ,  0.02052528,  0.00756169,  0.0342629 ,
#           0.03842212, -0.04316542,  0.03130146, -0.04958304,
#           0.022647  ,  0.04616351],
#         [-0.03410431,  0.03842289,  0.03138549, -0.02436343,
#           0.04305479, -0.04059948,  0.03519707, -0.01606737,
#           0.01461433,  0.00918099]],
#
#        [[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.01201606,  0.01414626,  0.03860701,  0.01598797,
#           0.04391552,  0.01895965,  0.03589279,  0.04442103,
#          -0.00563138,  0.00528693],
#         [-0.01244445, -0.02957804,  0.00261693,  0.02056589,
#          -0.02634252,  0.00701339,  0.03048749, -0.02724193,
#          -0.02480011, -0.02679308],
#         [-0.0077255 ,  0.02052528,  0.00756169,  0.0342629 ,
#           0.03842212, -0.04316542,  0.03130146, -0.04958304,
#           0.022647  ,  0.04616351],
#         [ 0.01656804,  0.03563049,  0.03778514, -0.00497509,
#          -0.03007882, -0.00686252, -0.03163241, -0.03673954,
#          -0.02302723,  0.00830907]],
#
#        [[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.01201606,  0.01414626,  0.03860701,  0.01598797,
#           0.04391552,  0.01895965,  0.03589279,  0.04442103,
#          -0.00563138,  0.00528693],
#         [ 0.0460918 ,  0.02237146, -0.02830622,  0.0203482 ,
#          -0.00450779, -0.02517904,  0.02715791,  0.00319326,
#           0.0229618 , -0.03519382],
#         [-0.0077255 ,  0.02052528,  0.00756169,  0.0342629 ,
#           0.03842212, -0.04316542,  0.03130146, -0.04958304,
#           0.022647  ,  0.04616351],
#         [ 0.0225221 ,  0.0255642 ,  0.04588219, -0.04818218,
#           0.04770743, -0.01901709,  0.02113725, -0.01904712,
#           0.04356316, -0.0477263 ]],
#
#        [[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.03943175, -0.00223524, -0.03879339,  0.01357785,
#           0.00541886,  0.0333172 ,  0.02747724, -0.04170643,
#          -0.00019109, -0.00400926],
#         [ 0.00786703, -0.04019492,  0.02320058,  0.01960525,
#           0.00648596, -0.0451557 , -0.032356  ,  0.03916432,
#          -0.03662927, -0.02929701],
#         [-0.02457031,  0.01344815,  0.03853485, -0.01716632,
#           0.01849297,  0.01376665,  0.04305632, -0.02610943,
#           0.03163337, -0.02335279],
#         [-0.0177376 ,  0.04302949,  0.03215745,  0.00195789,
#           0.02905211, -0.02197355,  0.01061466,  0.04689417,
#           0.0374479 , -0.03676056],
#         [ 0.01841165, -0.00662015, -0.00806756, -0.04986357,
#           0.00239659, -0.02116119, -0.03452837, -0.02592146,
#           0.00221968,  0.01726449]],
#
#        [[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.03943175, -0.00223524, -0.03879339,  0.01357785,
#           0.00541886,  0.0333172 ,  0.02747724, -0.04170643,
#          -0.00019109, -0.00400926],
#         [ 0.00786703, -0.04019492,  0.02320058,  0.01960525,
#           0.00648596, -0.0451557 , -0.032356  ,  0.03916432,
#          -0.03662927, -0.02929701],
#         [-0.02457031,  0.01344815,  0.03853485, -0.01716632,
#           0.01849297,  0.01376665,  0.04305632, -0.02610943,
#           0.03163337, -0.02335279],
#         [-0.0177376 ,  0.04302949,  0.03215745,  0.00195789,
#           0.02905211, -0.02197355,  0.01061466,  0.04689417,
#           0.0374479 , -0.03676056],
#         [ 0.03019584, -0.01650257, -0.01270477,  0.03228343,
#           0.01262662, -0.00775756, -0.038763  ,  0.02451371,
#           0.03509105, -0.03002742]],
#
#        [[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.04330385,  0.02811031, -0.01588885,  0.01437879,
#          -0.02092292,  0.01069441,  0.02844233,  0.02711227,
#           0.03068027, -0.04230767],
#         [-0.01201606,  0.01414626,  0.03860701,  0.01598797,
#           0.04391552,  0.01895965,  0.03589279,  0.04442103,
#          -0.00563138,  0.00528693],
#         [ 0.04151532,  0.03411068,  0.03987074,  0.03546873,
#           0.01608801, -0.01781162, -0.02273847,  0.03153444,
#           0.04338429,  0.01653111],
#         [-0.0077255 ,  0.02052528,  0.00756169,  0.0342629 ,
#           0.03842212, -0.04316542,  0.03130146, -0.04958304,
#           0.022647  ,  0.04616351],
#         [-0.01854811, -0.01791514,  0.04724724,  0.02105384,
#          -0.02230383,  0.00225876,  0.03043086, -0.04365665,
#           0.02386905, -0.01167769]],
#
#        [[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.03979475,  0.01099303, -0.04791113,  0.0409112 ,
#           0.02838056, -0.00054134,  0.03435625,  0.02689033,
#           0.02877225, -0.04858631],
#         [-0.04869888, -0.03210165, -0.0386371 , -0.04933092,
#          -0.02043142,  0.04426396, -0.03786285,  0.03426195,
#           0.03780207, -0.02630785],
#         [-0.01895323,  0.0282509 , -0.01250643, -0.04867684,
#          -0.04153818,  0.00847733,  0.03794911,  0.01347928,
#          -0.01910175,  0.01006696],
#         [-0.0177376 ,  0.04302949,  0.03215745,  0.00195789,
#           0.02905211, -0.02197355,  0.01061466,  0.04689417,
#           0.0374479 , -0.03676056]]], dtype=float32)

# %%
input_data = np.array(embedded_docs[0])
input_data
# Out:
# array([   0,    0,    0,    0, 7568, 5854,  432, 1477])

# %%
input_data = input_data.reshape(1, input_data.shape[0])

# %%
predictions = model.predict(input_data)
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# array([[[ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [ 0.01787451,  0.04075632, -0.04313667, -0.02808738,
#          -0.02817326,  0.04079023,  0.03307401, -0.03037354,
#          -0.04662713,  0.01523477],
#         [-0.01201606,  0.01414626,  0.03860701,  0.01598797,
#           0.04391552,  0.01895965,  0.03589279,  0.04442103,
#          -0.00563138,  0.00528693],
#         [-0.01244445, -0.02957804,  0.00261693,  0.02056589,
#          -0.02634252,  0.00701339,  0.03048749, -0.02724193,
#          -0.02480011, -0.02679308],
#         [-0.0077255 ,  0.02052528,  0.00756169,  0.0342629 ,
#           0.03842212, -0.04316542,  0.03130146, -0.04958304,
#           0.022647  ,  0.04616351],
#         [-0.03410431,  0.03842289,  0.03138549, -0.02436343,
#           0.04305479, -0.04059948,  0.03519707, -0.01606737,
#           0.01461433,  0.00918099]]], dtype=float32)
